# %% [markdown]
# ## START

# %% [markdown]
# The dataset contains comprehensive information about individuals insured by a Healthcare Organization, including demographic details such as age,gender,BMI,children,smoker,region and expenses

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Using the command %matplotlib inline helps to display matplotlib directly in juypter notebook leads to automatic display and interactive plots.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  The above code is used to supress warnings in python arise due to deprecated functions, potential issues, or other non-critical issues.

# %%
data = pd.read_csv(r'C:\Users\admin\OneDrive\Desktop\mini\insurance.csv')

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# ## DATA EXPLORATION

# %% [markdown]
# The dataset is explored with various method to understand the data set, handling missing values and others.

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.columns.values
# Out:
# array(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
data.describe(include='object')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
data.describe(include='object').T
# Out:
#        count unique        top  freq
# sex     1338      2       male   676
# smoker  1338      2         no  1064
# region  1338      4  southeast   364

# %% [markdown]
# - There are seven columns in this dataset.
# - There is no null value.
# - There is only one duplicate value.
# - The columns includes age, gender, BMI, children, smoker, region and expenses
# - The number of male is high with the frequency of 676
# - The number of people who doesn't smoke is high with the frequency of 1064

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# Analysis a data gives more knowledge on the dataset

# %%
plt.rcParams['figure.figsize'] = (9,5)
plt.rcParams['figure.dpi'] = 170
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %%
plt.xlabel('Age')
plt.ylabel('Expenses')
plt.plot(data['age'], data['expenses'], 'ro');

# %% [markdown]
# Age increases drastically

# %%
sns.scatterplot(x = 'age', y = 'expenses', hue='sex', data=data);

# %%
sns.distplot(data['children'], color = 'r');

# %%
sns.boxplot(x = 'smoker', y = 'expenses', data = data);
